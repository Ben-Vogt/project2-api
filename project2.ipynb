# %% [markdown]
# # Project 2: Web Scraping and API access

# %%
# !pip install beautifulsoup4

# %% [markdown]
# ## Part 1: Explore the html for Wikipedia articles.

# %% [markdown]
# ### A. Using inspect element, copy the html code for a table.

# %% [markdown]
# <table class="infobox biota" style="text-align: left; width: 200px; font-size: 100%">
#
# <tbody><tr>
# <th colspan="2" style="color:inherit; text-align: center; background-color: rgb(235,235,210)"><i>Epionitis</i>
# </th></tr>
#
# <tr>
# <th colspan="2" style="color:inherit; min-width:15em; text-align: center; background-color: rgb(235,235,210)"><a href="/wiki/Taxonomy_(biology)" title="Taxonomy (biology)">Scientific classification</a>
# </th></tr>
#
# <tr>
# <td>Kingdom:
# </td>
# <td><div style="display:inline" class="kingdom"><a href="/wiki/Animal" title="Animal">Animalia</a></div>
# </td></tr>
#
# <tr>
# <td>Phylum:
# </td>
# <td><div style="display:inline" class="phylum"><a href="/wiki/Arthropod" title="Arthropod">Arthropoda</a></div>
# </td></tr>
#
# <tr>
# <td>Class:
# </td>
# <td><div style="display:inline" class="class"><a href="/wiki/Insect" title="Insect">Insecta</a></div>
# </td></tr>
#
# <tr>
# <td>Order:
# </td>
# <td><div style="display:inline" class="order"><a href="/wiki/Beetle" title="Beetle">Coleoptera</a></div>
# </td></tr>
#
# <tr>
# <td>Suborder:
# </td>
# <td><div style="display:inline" class="suborder"><a href="/wiki/Polyphaga" title="Polyphaga">Polyphaga</a></div>
# </td></tr>
#
# <tr>
# <td>Infraorder:
# </td>
# <td><div style="display:inline" class="infraorder"><a href="/wiki/Scarabeiformia" class="mw-redirect" title="Scarabeiformia">Scarabeiformia</a></div>
# </td></tr>
#
# <tr>
# <td>Superfamily:
# </td>
# <td><div style="display:inline" class="superfamily"><a href="/wiki/Scarabaeoidea" title="Scarabaeoidea">Scarabaeoidea</a></div>
# </td></tr>
#
# <tr>
# <td>Family:
# </td>
# <td><div style="display:inline" class="family"><a href="/wiki/Scarabaeidae" title="Scarabaeidae">Scarabaeidae</a></div>
# </td></tr>
#
# <tr>
# <td>Genus:
# </td>
# <td><div style="display:inline" class="genus"><i><b>Epionitis</b></i></div>
# </td></tr>
#
# </tbody></table>

# %% [markdown]
# ### B. Using inspect element, find the html syntax for a link.

# %%
<a rel="nofollow" class="external text" href="https://web.archive.org/web/20100123153526/http://www.itis.gov/servlet/SingleRpt/SingleRpt">"Archived copy"</a>

# %% [markdown]
# ### C. Using inspect element, find the html syntax for linking an image

# %%
<img alt="Żurawki is located in Poland" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Poland_adm_location_map.svg/250px-Poland_adm_location_map.svg.png" decoding="async" width="250" height="243" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Poland_adm_location_map.svg/375px-Poland_adm_location_map.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Poland_adm_location_map.svg/500px-Poland_adm_location_map.svg.png 2x" data-file-width="861" data-file-height="837">

# %% [markdown]
# ## Part 2: Explore one Wikipedia page with the beautifulsoup package

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#save and print the text content of a page with all tags removed
page = requests.get("https://en.wikipedia.org/wiki/Batman").text

# %%
with open("batman_page.html", "w", encoding='utf-8') as file:
    file.write(page)

# %%
soup = BeautifulSoup(page)

# %%
print(soup.get_text())
# Out:
# Batman - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload fileSpecial pages
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Appearance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Donate
#
# Create account
#
# Log in
#
#
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
# Donate Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1
# Publication history
#
#
#
#
# Toggle Publication history subsection
#
#
#
#
#
# 1.1
# Creation and early history
#
#
#
#
#
#
#
#
# ...

# %%
#download an image with beautifulsoup and save it in this repository
images = soup.find_all("img")
images[4]["src"]
# Out:
# '//upload.wikimedia.org/wikipedia/en/thumb/c/c7/Batman_Infobox.jpg/220px-Batman_Infobox.jpg'

# %%
img = requests.get("https:"+images[4]["src"])

# %% [markdown]
# for some reason Wikipedia can shorten their links, maybe because they're referring to images hosted elsewhere on their own site? But means you need to add the https: on your own.

# %%
with open("batman_img.jpg", "wb") as file:
    file.write(img.content)

# %%
#find all the links in a page with beautifulsoup
#print the first 100 characters of ten of these links
links = soup.find_all("a")
for i in range(10):
    print(links[i]["href"][:100])
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal

# %% [markdown]
# ## Part 3: Downloading scripts

# %%
scripts=pd.read_csv('pudding_data.csv')

# %%
scripts
# Out:
#         imdb_id  script_id             title  year  \
# 0     tt0019777       4031     The Cocoanuts  1929
# 1     tt0021884       8521      Frankenstein  1931
# 2     tt0022054       1086   The Last Flight  1931
# 3     tt0022626       1631  American Madness  1932
# 4     tt0022958       2438       Grand Hotel  1932
# ...         ...        ...               ...   ...
# 1995  tt3733778       8533     Pay the Ghost  2015
# 1996  tt3808342       5499       Son of Saul  2015
# 1997  tt3850214       8056              Dope  2015
# 1998  tt3859076       5507             Truth  2015
# 1999  tt4270516       5410           Grandma  2015
#
#       gross (inflation-adjusted)  \
# 0                            NaN
# 1                          298.0
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1995                         NaN
# 1996                         0.0
# 1997                        18.0
# ...

# %%
#using the links in the "link" column, download the first 1000 characters of each script
#use requests and bs4, remember to remove all html tags
def transformLink(link):
    return link if "http" in link else "http://" + link

count = 0
texts = []
for link in scripts["link"]:
    html = "lol"
    try:
        html = requests.get(transformLink(link)).text
    except Exception as e:
        count += 1
    soup = BeautifulSoup(html)
    texts.append(soup.get_text()[:1000])
print(count)
# Out:
# 912

# %%
#add a new column to the df with the text downloaded
#save this new dataframe as "pudding_texts.csv"
scripts["texts"] = texts

# %%
scripts.to_csv("pudding_texts.csv")

# %% [markdown]
# ## Part 4: TMDB database

# %% [markdown]
# #### Browse the documentation at https://developer.themoviedb.org/reference/intro/getting-started. Create an account to authenticate

# %%
# Install the python-dotenv package
# %pip install python-dotenv
%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install tmdbsimple
# Out:
# ...
#   Using cached tmdbsimple-2.9.1-py3-none-any.whl.metadata (6.9 kB)
# ...
# Using cached tmdbsimple-2.9.1-py3-none-any.whl (38 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tmdbsimple as tmdb

# %% [markdown]
# I used a seperate file not tracked by the github repo to house the API key I obtained, to avoid posting it on github. To run this code you will likely need your own valid API key.

# %%
from dotenv import load_dotenv
import os

# Load the api key from the .env file in the same directory as this notebook
load_dotenv()
tmdb.API_KEY = os.getenv("TMDB_API_KEY")

#Set a request timeout of 5 seconds, because I'm impatient.
tmdb.REQUESTS_TIMEOUT = 5

# %%
#create a dataset of the movies in theaters now. Include metadata fields you are interested in. 
mov = tmdb.Movies()
now_playing = mov.now_playing()
movies = []
for page in range(1, now_playing["total_pages"] + 1):
    data = mov.now_playing(page=page)
    movies.extend(data["results"])
    
print(len(movies))
# Out:
# 4100

# %% [markdown]
# I guess I kind of just included all the metadata fields... I don't really have much interest in movies anyways.

# %%
movie_df = pd.DataFrame(movies)
movie_df
# Out:
#       adult                     backdrop_path         genre_ids       id  \
# 0     False  /9nhjGaFLKtddDPtPaX5EmKqsWdH.jpg  [10749, 878, 53]   950396
# 1     False  /gFFqWsjLjRfipKzlzaYPD097FNC.jpg      [28, 53, 80]  1126166
# 2     False  /kEYWal656zP5Q2Tohm91aw6orlT.jpg   [18, 35, 10749]  1064213
# 3     False  /qfAfE5auxsuxhxPpnETRAyTP5ff.jpg     [28, 53, 878]   822119
# 4     False  /b3mdmjYTEL70j7nuXATUAD9qgu4.jpg      [16, 14, 12]   823219
# ...     ...                               ...               ...      ...
# 4095  False  /2luslCjJvDFdyx3Ggf1ZET6N7iw.jpg                []  1443956
# 4096  False  /q83QkSzEHNlZmT9n5hWvu8ZgnjM.jpg          [18, 28]  1443939
# 4097  False                              None              [99]  1443938
# 4098  False  /g3sVBquuS3RSDPcAnomATqI9FDG.jpg          [16, 14]  1443933
# 4099  False  /yw72Cl1GAYYGjcIEt4hHpUdsGSl.jpg          [37, 28]  1443929
#
#      original_language                    original_title  \
# ...

# %%
#download the movie posters for 10 of these movies and save them to this repository
base_url = tmdb.Configuration().info()["images"]["base_url"]
for i in range(0, 10):
    img = requests.get(base_url+movie_df["poster_path"][i])
    with open(movie_df["title"][i]+".jpg", "wb") as file:
        file.write(img.content)
